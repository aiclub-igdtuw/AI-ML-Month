# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"honeyproduction.csv")

# %%
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %% [markdown]
# Ques1.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
#the quantitative data are:
                       #1. numcol
                       #2. yieldpercol  
                       #3  totalprod    
                       #4  stocks      
                       #5  priceperlb   
                       #6  prodvalue     
                       #7  year

# %%
#The Quantitative data is state
df.dtypes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %% [markdown]
# Ques 2.

# %%
import numpy as np
import seaborn as sns
sns.pairplot(df)

# %%
x = sns.heatmap(df.corr(), annot=True)

# %%
honey_prod_over_years = df.groupby("year").mean()

# %%
honey_prod_over_years[["numcol","yieldpercol","totalprod","stocks","priceperlb","prodvalue"]].plot

# %% [markdown]
# Ques3.

# %%
plt.bar(x=df['year'],
        height=df['totalprod'])
# Out:
# <BarContainer object of 626 artists>

# %%
#There is declining production trend over the years

# %% [markdown]
# Ques4.

# %%
plt.bar(x=df['totalprod'],
        height=df['prodvalue'])
# Out:
# <BarContainer object of 626 artists>

# %%
#There is no BAR plot observed in between "totalprod" and "valueprod"
#There is scatter plot between them.

# %% [markdown]
# Ques5.

# %%
plt.bar(x=df['year'],
        height=df['numcol'])
# Out:
# <BarContainer object of 626 artists>

# %%
#Graph between numberofColumns over years

# %% [markdown]
# Ques6.

# %%
plt.bar(x=df['year'],
        height=df['yieldpercol'])
# Out:
# <BarContainer object of 626 artists>

# %%
plt.bar(x=df['state'],
        height=df['totalprod'])
# Out:
# <BarContainer object of 626 artists>

# %%
#the state with maximum total production is ND the state with minimum production is SC

# %% [markdown]
# Ques7.

# %%
plt.bar(x=df['year'],
        height=df['prodvalue'])
# Out:
# <BarContainer object of 626 artists>

# %%
a=np.array(df["totalprod"])

# %%
b=np.array(df['year'])
c=np.array(df['prodvalue'])

# %%
plt.plot(b, c) 
plt.show()

# %%
plt.plot(b, a,'g^')
plt.show()

# %%
#there is incresing production value over years when total production is declining
