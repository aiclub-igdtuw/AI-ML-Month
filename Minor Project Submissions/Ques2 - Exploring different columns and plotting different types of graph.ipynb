# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the dataset
df = pd.read_csv("COVID clinical trials.csv")

# %%
# To Set max_colwidth to 1000
pd.set_option('display.max_colwidth', 1000)
df
# Out:
#       Rank   NCT Number  \
# 0        1  NCT04785898
# 1        2  NCT04595136
# 2        3  NCT04395482
# 3        4  NCT04416061
# 4        5  NCT04395924
# ...    ...          ...
# 5778  5779  NCT04011644
# 5779  5780  NCT04681339
# 5780  5781  NCT04740229
# 5781  5782  NCT04804917
# 5782  5783  NCT04680000
#
#                                                                                                                       Title  \
# 0                      Diagnostic Performance of the ID Now™ COVID-19 Screening Test Versus Simplexa™ COVID-19 Direct Assay
# 1     Study to Evaluate the Efficacy of COVID19-0001-USR in Patients With Mild/or Moderate COVID-19 Infection in Outpatient
# 2                                                                    Lung CT Scan Analysis of SARS-CoV2 Induced Lung Injury
# 3                                                        The Role of a Private Hospital in Hong Kong Amid COVID-19 Pandemic
# ...

# %%
# To Set the max columns to none
pd.set_option('display.max_columns', None)
df
# Out:
#       Rank   NCT Number  \
# 0        1  NCT04785898
# 1        2  NCT04595136
# 2        3  NCT04395482
# 3        4  NCT04416061
# 4        5  NCT04395924
# ...    ...          ...
# 5778  5779  NCT04011644
# 5779  5780  NCT04681339
# 5780  5781  NCT04740229
# 5781  5782  NCT04804917
# 5782  5783  NCT04680000
#
#                                                                                                                       Title  \
# 0                      Diagnostic Performance of the ID Now™ COVID-19 Screening Test Versus Simplexa™ COVID-19 Direct Assay
# 1     Study to Evaluate the Efficacy of COVID19-0001-USR in Patients With Mild/or Moderate COVID-19 Infection in Outpatient
# 2                                                                    Lung CT Scan Analysis of SARS-CoV2 Induced Lung Injury
# 3                                                        The Role of a Private Hospital in Hong Kong Amid COVID-19 Pandemic
# ...

# %%
# To get the number of columns
len(df.columns)
# Out:
# 27

# %%
We have performed three operations on the different columns in the given dataset:
Set max_colwidth to 1000
Set the max columns to none
To get the number of columns

# %%
For Data Visualisation, we're using three methods to represent our data:
Method-1 : Through Pie Chart
Method-2 : Through Bar Graph
Method-3 : Through Histogram

# %%
# Method 1 - Plot the data using pie chart method
sizes = [2805, 1025, 1004, 526, 181, 107, 74]
labels = 'Recruiting', 'Completed', 'Not yet recruiting', 'Active, not recruiting', 'Enrolling by invitation', 'Withdrawn', 'Terminated'
colors = ( "orange", "cyan", "brown", "grey", "indigo", "yellow", "red")
textprops = {"fontsize":18}
plt.pie(sizes, labels = labels, colors = colors, autopct='%1.0f%%')
plt.title('Recruitment Status', fontsize = 15)
plt.axis('equal')
plt.show()

# %%
# Method 2 - Plot the data using bar chart method
sizes = [2805, 1025, 1004, 526, 181, 107, 74]
labels = 'Recruiting', 'Completed', 'Not yet recruiting','Active, not recruiting', 'Enrolling by invitation','Withdrawn', 'Terminated'
colors = ("orange", "cyan", "brown", "grey", "indigo", "yellow", "red")
plt.bar(labels, sizes, width=0.5, color = colors, edgecolor="red")
plt.rcParams["figure.figsize"] = (18,11.5)
plt.title("Recruitment Status", fontsize = 15)
plt.xlabel("Status of Study", fontsize = 15)
plt.ylabel("Count", fontsize = 15)
plt.show()

# %%
# Method 3 - Plot the data using histogram method
x = [74, 181, 1025, 2085, 1004, 526, 107, 74]
y = [0, 500, 1000, 1500, 2100]
plt.hist(x,y)
plt.title("Recruitment Status")
plt.xlabel("Status of Study")
plt.xticks(y)
plt.ylabel("Count")
plt.show()

# %%
Among Pie Chart, Bar Chart and Histogram; Bar Chart is better plot as it depicts the exact numeric values against distinct categories.
Pie Chart represent data in terms of percentages as a whole.
