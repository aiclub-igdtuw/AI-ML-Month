# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns

# %%
var=pd.read_csv(r"C:\Users\hp\Data_Visual\superstore_dataset.csv" , encoding=('ISO-8859-1'))

# %%
plt.rcParams["figure.figsize"] = (8,5.5)

# %% [markdown]
# # Q1: Box plot for all numeric variable and check for outliers

# %%
plt.boxplot(var.Sales)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20cc93beef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20cc93bf490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20cc93bec20>],
#  'medians': [<matplotlib.lines.Line2D at 0x20cc93bfa30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20cc93bfd00>],
#  'means': []}

# %% [markdown]
# # There are a lot of outliers that's why the boundaries of the box plot are squeezed

# %%
plt.boxplot(var.Discount)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20cc94c2590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20cc94c2b30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20cc94c22c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20cc94c30d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20cc94c33a0>],
#  'means': []}

# %%
plt.boxplot(var.Profit)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20cc954c790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20cc954cd30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20cc954c4c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20cc954d2d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20cc954d5a0>],
#  'means': []}

# %%
plt.boxplot(var.Quantity)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20cc959bbe0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20cc95d41c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20cc959b910>],
#  'medians': [<matplotlib.lines.Line2D at 0x20cc95d4760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20cc95d4a30>],
#  'means': []}

# %% [markdown]
# # Q6 Analyze the city wise performance of order counts

# %%
plt.figure(figsize=(20,10))
strg=var.groupby(['City'])['Quantity'].sum()
sns.countplot(x=strg, data=var)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='count'>

# %% [markdown]
# # Q5 Create bar plot for Sub-category wise order counts.Which sub-Category has maximum order and minimum order

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Sub-Category', data=var)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %% [markdown]
# # Here we can see that binders(Sub-category) has maximum order counts and Tables(Sub-category) has minimum order counts
