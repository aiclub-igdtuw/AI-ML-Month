# %% [markdown]
# SUPER STORE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
a=pd.read_csv("/content/Uniqlo(FastRetailing) 2012-2016 Training - stocks2012-2016.csv")
a.head(3)
# Out:
#          Date   Open   High    Low  Close  Volume  Stock Trading
# 0  12/30/2016  42120  42330  41700  41830  610000   2.562803e+10
# 1  12/29/2016  43000  43220  42540  42660  448400   1.918823e+10
# 2  12/28/2016  43940  43970  43270  43270  339900   1.478067e+10

# %% [markdown]
# QUESTION 1.
# 1)Stock Trading is highest when open value is around 29,000.
# 2)And as such there is no regular trend between open and stock trading.

# %%
b=a["Open"]
c=a["Stock Trading"]
plt.plot(b,c)
plt.xlabel("OPEN")
plt.ylabel("STOCK TRADING")
plt.style.use("seaborn")
plt.show()

# %% [markdown]
# QUESTION 2   1. First I found the standard deviation of low and high price.
#               2. Difference in high and low value of SD is 240.66 .

# %%
SD=a[['Low','High']].std() 
MEAN=a[["Low","High"]].mean()
print("MEAN IS\n " ,MEAN)
print("STANDARD DEVIATION IS\n" ,SD)
# Out:
# MEAN IS
#   Low     33347.903752
# High    34178.784666
# dtype: float64
# STANDARD DEVIATION IS
#  Low     10695.664102
# High    10936.326802
# dtype: float64

# %%
price_change=10936.326802- 10695.664102
print("change in SD of high and low price is ", price_change)
# Out:
# change in SD of high and low price is  240.66269999999895

# %% [markdown]
# QUESTION 3 1.Fist I found the median of open,high,low,close,volume.
#            2.Then I created two lists ,one contained the median values   and second one contained the names of the column.
#            3.Then I plotted a pie chart.

# %%
a.head(2)
# Out:
#          Date   Open   High    Low  Close  Volume  Stock Trading
# 0  12/30/2016  42120  42330  41700  41830  610000   2.562803e+10
# 1  12/29/2016  43000  43220  42540  42660  448400   1.918823e+10

# %%
O=a["Open"].median()
H=a["High"].median()
L=a["Low"].median()
C=a["Close"].median()
V=a["Volume"].median()
print(O,H,L,C,V)
# Out:
# 34445.0 34835.0 33925.0 34412.5 626000.0

# %%
A=["34445.0" ,"34835.0","33925.0", "34412.5" ,"626000.0"]
B=["Open","High","Low","Close","Volume"]

# %%
plt.pie(A,labels=B,explode=[0.2,0.1,0.2,0.1,0])
plt.style.use("seaborn-deep")
plt.show()

# %% [markdown]
# QUESTION 4  1.First I found the mean of volume .
#            2.Then I found the mean of all other columns given in question .
#            3. And ploted a pie chart.

# %%
M=a["Volume"].mean()
N=a["High"].mean()
P=a["Low"].mean()
R=a["Open"].mean()
S=a["Close"].mean()
print(M," ,",N," ,",P," ,"," ,",R," ,",S)
# Out:
# 727555.6280587276  , 34178.78466557912  , 33347.90375203915  ,  , 33754.41680261011  , 33760.58319738989

# %%
X=[727555.6280587276  , 34178.78466557912  , 33347.90375203915  ,  33754.41680261011  , 33760.58319738]
Y=["Volume","High","Low","Open","Close"]
plt.pie(X,labels=Y)
plt.show()

# %% [markdown]
# QUESTION 5

# %%
a.head(1)
# Out:
#          Date   Open   High    Low  Close  Volume  Stock Trading
# 0  12/30/2016  42120  42330  41700  41830  610000   2.562803e+10

# %%
a["Date"]=pd.to_datetime(a["Date"])

# %%
S=a["Date"]
T=a["Stock Trading"]
plt.plot(S,T)
plt.show()
U=a["Open"]
V=a["Close"]
plt.plot(U,V)
plt.style.use("seaborn-bright")
plt.show()

# %% [markdown]
# QUESTION 6

# %%
P=a["Stock Trading"]
M=P.pct_change()
print("PERCENTAGE CHANGE IN STOCK TRADING IS:",M)
# Out:
# PERCENTAGE CHANGE IN STOCK TRADING IS: 0            NaN
# 1      -0.251280
# 2      -0.229701
# 3       0.179107
# 4      -0.107883
#           ...
# 1221    0.944171
# 1222   -0.109174
# 1223   -0.214122
# 1224   -0.338937
# 1225    0.097996
# Name: Stock Trading, Length: 1226, dtype: float64
