# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka-GA/AI-ML-Month/blob/main/minor_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **AI/ML MONTH PROBLEM STATEMENTS**

# %% [markdown]
# # **LOAN DEFAULT PREDICTION**

# %% [markdown]
# Q1) What is the number of people who will be given a grace period of exactly 15 days.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
d=pd.read_csv(('/content/drive/My Drive/Colab Notebooks/loan.csv'))

# %%
d             #COMPLETE DATASET
# Out:
#       Index  Employed  Bank Balance  Annual Salary  Defaulted?
# 0         1         1       8754.36      532339.56           0
# 1         2         0       9806.16      145273.56           0
# 2         3         1      12882.60      381205.68           0
# 3         4         1       6351.00      428453.88           0
# 4         5         1       9427.92      461562.00           0
# ...     ...       ...           ...            ...         ...
# 9995   9996         1       8538.72      635908.56           0
# 9996   9997         1       9095.52      235928.64           0
# 9997   9998         1      10144.92      703633.92           0
# 9998   9999         1      18828.12      440029.32           0
# 9999  10000         0       2411.04      202355.40           0
#
# [10000 rows x 5 columns]

# %%
d1=d[(d['Bank Balance']>5000) &(d['Annual Salary']>100000)&(d['Employed']==1)]

# %%
d1 # it will give the list of people  who will be given a grace period of exactly 15 days
# Out:
#       Index  Employed  Bank Balance  Annual Salary  Defaulted?
# 0         1         1       8754.36      532339.56           0
# 2         3         1      12882.60      381205.68           0
# 3         4         1       6351.00      428453.88           0
# 4         5         1       9427.92      461562.00           0
# 6         7         1       9906.12      298862.76           0
# ...     ...       ...           ...            ...         ...
# 9993   9994         1      11266.08      679601.40           0
# 9995   9996         1       8538.72      635908.56           0
# 9996   9997         1       9095.52      235928.64           0
# 9997   9998         1      10144.92      703633.92           0
# 9998   9999         1      18828.12      440029.32           0
#
# [5298 rows x 5 columns]

# %% [markdown]
# Ans 1) 5298 people will be given the grace period of exactly 15 days as it has 5298 row entries in the the conditioned tabled

# %% [markdown]
# Q2) Find the maximum fine that can be levied by the bank in the period of 15 days.

# %%
n=d['Bank Balance'].max()        # gives the max bank balance of the table.

# %%
max_fine=n*(0.025)*15

# %%
max_fine
# Out:
# 11944.44

# %% [markdown]
#  Ans 2)if the given 15 days is the grace period then fine generated is 0 .otherwise maximum fine generaed by bank in a time period after grace period for 15 days is 11944.44.

# %% [markdown]
# Q3)Assuming tha all the people falling into the category of defaulters have not paid their EMI in the grace period what is the total amount being generated by the bank as a part of fine

# %%
d2=d[d['Defaulted?']==1]            # it will give the list of defaulters.

# %%
no_of_days =  1                                         #int(input("enter number of defaulted days : "))
total_fine_generated=no_of_days*(0.025)*d2['Bank Balance']

# %%
d2['Total Fine']=total_fine_generated       #will create a new column  in which fine generted per day is given

# %%
d2
# Out:
#       Index  Employed  Bank Balance  Annual Salary  Defaulted?  Total Fine
# 136     137         0      17844.00      214252.80           1     446.100
# 173     174         0      26469.60      171257.88           1     661.740
# 201     202         0      21296.28      244314.12           1     532.407
# 206     207         1      22675.20      587474.04           1     566.880
# 209     210         0      22792.68      247862.40           1     569.817
# ...     ...       ...           ...            ...         ...         ...
# 9912   9913         1      25786.80      531719.04           1     644.670
# 9921   9922         0      19534.80      210564.00           1     488.370
# 9949   9950         1      21003.00      618947.28           1     525.075
# 9951   9952         1      18187.32      584262.12           1     454.683
# 9978   9979         1      26429.52      567447.12           1     660.738
#
# [333 rows x 6 columns]

# %%
 total_fine=d2['Total Fine'].sum()
 total_fine
# Out:
# 174607.371

# %% [markdown]
#  Ans 3) total fine generated by bank each day is 174607.371.

# %% [markdown]
# Q4) Use a suitable plot to show the differences in bank balance of the people who are eligible for a grace period and those  who are not

# %%
sns.catplot( x='Employed',y='Bank Balance',data=d, kind='box')

# %% [markdown]
#  Ans 4)  This plot shows the difference in bank balance of the people who are eligible for a grace period and those  who are not. 0 shows eligible whereas 1 shows not eligible

# %% [markdown]
# Q5)  find the difference in median of the bank balance of the people who are  eligible for grace period and original value.

# %%
d3=d[(d['Employed']==0)]
d3 ##only those who are eligible for grace period
# Out:
#       Index  Employed  Bank Balance  Annual Salary  Defaulted?
# 1         2         0       9806.16      145273.56           0
# 5         6         0      11035.08       89898.72           0
# 7         8         0       9704.04      211205.40           0
# 10       11         0          0.00      262452.84           0
# 11       12         0      14646.96      159222.72           0
# ...     ...       ...           ...            ...         ...
# 9980   9981         0       9240.24      164217.48           0
# 9986   9987         0       4815.96      183984.24           0
# 9989   9990         0      11991.36      240160.20           0
# 9994   9995         0       2068.92      179471.28           0
# 9999  10000         0       2411.04      202355.40           0
#
# [2944 rows x 5 columns]

# %%
median1=d3['Bank Balance'].median()

# %%
d['difference']=d['Bank Balance']-median1         # it will give you a new column difference in datset d which will have the difference in entire original value dataset and median of eligible people.

# %%
d
# Out:
#       Index  Employed  Bank Balance  Annual Salary  Defaulted?  difference
# 0         1         1       8754.36      532339.56           0    -3005.52
# 1         2         0       9806.16      145273.56           0    -1953.72
# 2         3         1      12882.60      381205.68           0     1122.72
# 3         4         1       6351.00      428453.88           0    -5408.88
# 4         5         1       9427.92      461562.00           0    -2331.96
# ...     ...       ...           ...            ...         ...         ...
# 9995   9996         1       8538.72      635908.56           0    -3221.16
# 9996   9997         1       9095.52      235928.64           0    -2664.36
# 9997   9998         1      10144.92      703633.92           0    -1614.96
# 9998   9999         1      18828.12      440029.32           0     7068.24
# 9999  10000         0       2411.04      202355.40           0    -9348.84
#
# [10000 rows x 6 columns]

# %%
d3['difference']=d3['Bank Balance']-median1  # it will give you a new column difference in datset d3 which will have the difference in original value dataset and median of eligible people.

# %%
d3
# Out:
#       Index  Employed  Bank Balance  Annual Salary  Defaulted?  difference
# 1         2         0       9806.16      145273.56           0    -1953.72
# 5         6         0      11035.08       89898.72           0     -724.80
# 7         8         0       9704.04      211205.40           0    -2055.84
# 10       11         0          0.00      262452.84           0   -11759.88
# 11       12         0      14646.96      159222.72           0     2887.08
# ...     ...       ...           ...            ...         ...         ...
# 9980   9981         0       9240.24      164217.48           0    -2519.64
# 9986   9987         0       4815.96      183984.24           0    -6943.92
# 9989   9990         0      11991.36      240160.20           0      231.48
# 9994   9995         0       2068.92      179471.28           0    -9690.96
# 9999  10000         0       2411.04      202355.40           0    -9348.84
#
# [2944 rows x 6 columns]

# %% [markdown]
# Ans 5) column in d gives difference in bank balance for all people and median of eligible people whereas in d3 column it gives difference in original value and median of bank balance only for eligible people.

# %% [markdown]
# Q6)Use a suitable graph to show the changes in the annual income of those people who are eligible for grace period and those who are not.

# %%
sns.displot(x='Annual Salary', hue='Employed',data=d)

# %% [markdown]
# Ans 6) blue protion shows for eligible people whereas orange portion shows for not eligible people.grey shaded region shows common portion for both.
